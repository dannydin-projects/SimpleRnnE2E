# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good',
]

### vocabulary size
voc_size = 10000

# %%
# One hot representation
onehot_repr = [one_hot(sentence, voc_size) for sentence in sent]
onehot_repr
# Out:
# [[2618, 3969, 1122, 6722],
#  [2618, 3969, 1122, 96],
#  [2618, 7610, 1122, 6166],
#  [3402, 2056, 6054, 1658, 1187],
#  [3402, 2056, 6054, 1658, 6904],
#  [5834, 2618, 5439, 1122, 9706],
#  [3042, 4826, 1321, 1658]]

# %%
# Word Embedding Representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

import numpy as np

# %%
sent_len = 8
embedded_docs = pad_sequences(onehot_repr, padding='pre', maxlen=sent_len)
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 2618, 3969, 1122, 6722],
#        [   0,    0,    0,    0, 2618, 3969, 1122,   96],
#        [   0,    0,    0,    0, 2618, 7610, 1122, 6166],
#        [   0,    0,    0, 3402, 2056, 6054, 1658, 1187],
#        [   0,    0,    0, 3402, 2056, 6054, 1658, 6904],
#        [   0,    0,    0, 5834, 2618, 5439, 1122, 9706],
#        [   0,    0,    0,    0, 3042, 4826, 1321, 1658]], dtype=int32)

# %%
# Feature Repr
dim =10

# %%
model = Sequential()
model.add(Embedding(voc_size, dim, input_shape=(sent_len,) ))
model.compile('adam', 'mse')
# Out:
# c:\Users\Danns\OneDrive\Desktop\Udemy_GenAI\Projects\venv\Lib\site-packages\keras\src\layers\core\embedding.py:100: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# array([[[ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.01239   , -0.01606832, -0.04237909,  0.03131148,
#          -0.01905488,  0.02152191,  0.04507541, -0.00692283,
#          -0.01618486,  0.01357938],
#         [ 0.01737439, -0.02179806, -0.00873638, -0.02738618,
#          -0.02094721, -0.03397286, -0.0382765 , -0.01100892,
#           0.01718256,  0.04139395],
#         [ 0.04999025, -0.0227375 ,  0.03563548, -0.04043808,
#          -0.00315956, -0.02761332, -0.03045303,  0.0031983 ,
#          -0.04389339,  0.01640472],
#         [-0.03162072,  0.03664118,  0.02212307,  0.02631648,
#           0.03582812,  0.01594169, -0.02608309, -0.02477588,
#           0.00720835, -0.03031931]],
#
#        [[ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.01239   , -0.01606832, -0.04237909,  0.03131148,
#          -0.01905488,  0.02152191,  0.04507541, -0.00692283,
#          -0.01618486,  0.01357938],
#         [ 0.01737439, -0.02179806, -0.00873638, -0.02738618,
#          -0.02094721, -0.03397286, -0.0382765 , -0.01100892,
#           0.01718256,  0.04139395],
#         [ 0.04999025, -0.0227375 ,  0.03563548, -0.04043808,
#          -0.00315956, -0.02761332, -0.03045303,  0.0031983 ,
#          -0.04389339,  0.01640472],
#         [-0.01478272, -0.01742123, -0.04708896, -0.02561779,
#          -0.02112054, -0.00028393, -0.0144781 , -0.0127659 ,
#           0.0223472 , -0.03529332]],
#
#        [[ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.01239   , -0.01606832, -0.04237909,  0.03131148,
#          -0.01905488,  0.02152191,  0.04507541, -0.00692283,
#          -0.01618486,  0.01357938],
#         [-0.00570178, -0.00077181,  0.03246076, -0.02948931,
#          -0.01991682,  0.01015406, -0.0416363 ,  0.01443628,
#           0.04879722, -0.022781  ],
#         [ 0.04999025, -0.0227375 ,  0.03563548, -0.04043808,
#          -0.00315956, -0.02761332, -0.03045303,  0.0031983 ,
#          -0.04389339,  0.01640472],
#         [-0.02915665,  0.01253588,  0.033148  , -0.0172432 ,
#           0.01781236,  0.02973387,  0.03196127,  0.00659668,
#          -0.01350715,  0.01789984]],
#
#        [[ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [-0.03104847,  0.03959152, -0.02807459, -0.04476441,
#           0.04782121, -0.04909499, -0.02349033,  0.02032195,
#          -0.03132919,  0.00964784],
#         [ 0.02031494,  0.04520987,  0.02185679,  0.00784731,
#          -0.00946259, -0.03766531,  0.02394946, -0.0387656 ,
#           0.0448438 , -0.0130496 ],
#         [-0.00354315,  0.04460514,  0.03632814, -0.0091378 ,
#           0.01758022,  0.02512229,  0.0310643 ,  0.04873559,
#          -0.03277721,  0.00690806],
#         [-0.00172185,  0.01812867,  0.00166921,  0.04255159,
#           0.04385055,  0.01099602, -0.01776319, -0.02455833,
#          -0.03855694, -0.02538936],
#         [ 0.0180893 , -0.02709517,  0.00116796, -0.00250166,
#           0.02498341, -0.00747333,  0.02769754, -0.03118702,
#          -0.02670331, -0.0061742 ]],
#
#        [[ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [-0.03104847,  0.03959152, -0.02807459, -0.04476441,
#           0.04782121, -0.04909499, -0.02349033,  0.02032195,
#          -0.03132919,  0.00964784],
#         [ 0.02031494,  0.04520987,  0.02185679,  0.00784731,
#          -0.00946259, -0.03766531,  0.02394946, -0.0387656 ,
#           0.0448438 , -0.0130496 ],
#         [-0.00354315,  0.04460514,  0.03632814, -0.0091378 ,
#           0.01758022,  0.02512229,  0.0310643 ,  0.04873559,
#          -0.03277721,  0.00690806],
#         [-0.00172185,  0.01812867,  0.00166921,  0.04255159,
#           0.04385055,  0.01099602, -0.01776319, -0.02455833,
#          -0.03855694, -0.02538936],
#         [ 0.00918771,  0.04071753,  0.0082996 ,  0.03085813,
#           0.04840912, -0.04705368, -0.04873358,  0.03599406,
#          -0.03036504, -0.03723756]],
#
#        [[ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.01794616,  0.00218568,  0.01382252, -0.03817923,
#           0.03002954, -0.0383876 , -0.03657724, -0.01102047,
#          -0.04652641, -0.0295597 ],
#         [ 0.01239   , -0.01606832, -0.04237909,  0.03131148,
#          -0.01905488,  0.02152191,  0.04507541, -0.00692283,
#          -0.01618486,  0.01357938],
#         [ 0.00775418, -0.02107487, -0.02992749, -0.01892362,
#          -0.03700882, -0.04146377,  0.01069241,  0.00670747,
#           0.03735975,  0.00548327],
#         [ 0.04999025, -0.0227375 ,  0.03563548, -0.04043808,
#          -0.00315956, -0.02761332, -0.03045303,  0.0031983 ,
#          -0.04389339,  0.01640472],
#         [-0.02823135, -0.03111343,  0.00308196,  0.01503186,
#          -0.03974418, -0.04228517,  0.04491327,  0.02508563,
#          -0.00029278, -0.01217095]],
#
#        [[ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.00537822, -0.02649572, -0.01055779, -0.02916423,
#          -0.04791616, -0.02624961, -0.02897251,  0.04661943,
#           0.03988378,  0.04066211],
#         [ 0.03505652, -0.02060568, -0.04578431,  0.04853291,
#           0.03888864,  0.04496627, -0.00232009,  0.04053977,
#          -0.01770736,  0.03849373],
#         [-0.00804547,  0.00870949, -0.02375457,  0.02504819,
#          -0.0481686 ,  0.01443416, -0.00302693,  0.04826912,
#          -0.04104609,  0.00273961],
#         [-0.01069578, -0.00441345, -0.03088841,  0.04967073,
#          -0.02268738,  0.03629864,  0.03206595, -0.04785835,
#          -0.03307524, -0.01669288],
#         [-0.00172185,  0.01812867,  0.00166921,  0.04255159,
#           0.04385055,  0.01099602, -0.01776319, -0.02455833,
#          -0.03855694, -0.02538936]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 2618, 3969, 1122, 6722], dtype=int32)
